# %%
df1=pd.read_csv('Ahmedabad_rent.csv')

# %%
df1.head()
# Out:
#   seller_type  bedroom layout_type      property_type     locality   price  \
# 0       OWNER        2         BHK          Apartment     Bodakdev  20,000
# 1       OWNER        1          RK   Studio Apartment      CG Road   7,350
# 2       OWNER        3         BHK          Apartment      Jodhpur  22,000
# 3       OWNER        2         BHK  Independent House       Sanand  13,000
# 4       OWNER        2         BHK  Independent House  Navrangpura  18,000
#
#    area    furnish_type     bathroom
# 0  1450       Furnished  2 bathrooms
# 1   210  Semi-Furnished  1 bathrooms
# 2  1900     Unfurnished  3 bathrooms
# 3  1285  Semi-Furnished  2 bathrooms
# 4  1600       Furnished  2 bathrooms

# %%
df1.locality.unique()
# Out:
# array(['Bodakdev', 'CG Road', 'Jodhpur', 'Sanand', 'Navrangpura',
#        'Moraiya', 'Vejalpur', 'Jivraj Park', 'Nikol', 'Shahibuag',
#        'Near Nirma University On SG Highway', 'Maninagar', 'Ghatlodiya',
#        'Nava Naroda', 'Shilaj', 'Saijpur Bogha', 'Jodhpur Village',
#        'Vastrapur', 'Satellite', 'Chandkheda', 'Bopal', 'Prahlad Nagar',
#        'Vasna', 'Shela', 'Makarba', 'Khokhra', 'Ghuma', 'Ghodsar',
#        'Memnagar', 'Nehru Nagar', 'Keshav Nagar', 'Science City',
#        'Thaltej', 'Naranpuraa', 'Jagatpur', 'Motera', 'Ambavadi',
#        'Shrinand Nagar', 'Satlasana',
#        'Near Vaishno Devi Circle On SG Highway', 'Paldi', 'Juhapura',
#        'Gota', 'Vatva', 'Godhavi', 'Ambli', 'Ranip', 'Zundal', 'Sola',
#        'Narol', 'Ellisbridge', 'Naryanpura', 'Gurukul', 'Narolgam',
#        'Usman Pura', 'Nana Chiloda', 'Sanathal', 'Khodiar Nagar',
#        'Anand Nagar', 'Satellite Society', 'Isanpur', 'Ramdev Nagar',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df1.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Ahmedabad local.csv', index=False)

# %%
a=df1.locality.unique()
len(a)
# Out:
# 203

# %%
df2=pd.read_csv('Bangalore_rent.csv')

# %%
df2.head()
# Out:
#   seller_type  bedroom layout_type      property_type  \
# 0       OWNER        2         BHK  Independent Floor
# 1       OWNER        2         BHK  Independent House
# 2       OWNER        2         BHK  Independent House
# 3       OWNER        1         BHK          Apartment
# 4       OWNER        3         BHK          Apartment
#
#                    locality   price  area    furnish_type     bathroom
# 0             kamakshipalya  20,000  1140  Semi-Furnished  2 bathrooms
# 1  Kadugodi Industrial Area   8,000   840  Semi-Furnished  2 bathrooms
# 2               Koramangala  21,000  1000  Semi-Furnished  2 bathrooms
# 3           Sadduguntepalya   9,000   550  Semi-Furnished  1 bathrooms
# 4                Chandapura  17,000  1230       Furnished  3 bathrooms

# %%
df2.locality.unique()
# Out:
# array(['kamakshipalya', 'Kadugodi Industrial Area', 'Koramangala',
#        'Sadduguntepalya', 'Chandapura', 'Yelahanka New Town',
#        'Bommanahalli', 'Kengeri Satellite Town', 'T Dasarahalli',
#        'Attibele', 'Kasavanahalli', 'Nandini Layout', 'Bharat Nagar',
#        'Kodihalli on Old Airport Road', 'Hebbal',
#        'Whitefield Hope Farm Junction', 'Banaswadi', 'Whitefield',
#        'Kogilu', 'Hennur', 'hongasandra bangalore', 'Banashankari',
#        'Krishnarajapura', 'Indira Nagar', 'Harlur', 'J. P. Nagar',
#        'Jakkur', 'Begur', 'BTM Layout', 'Basavanagudi', 'Padmanabhanagar',
#        'Kadugodi', 'Rajajinagar', 'Bagalakunte', 'Vidyaranyapura',
#        'Vibhutipura', 'Electronic City Phase 1', 'Kaggadasapura',
#        'Kannur', 'Bendre Nagar', 'Mathikere', 'Kothanur', 'Munnekollal',
#        'Electronic City Phase II', 'JP Nagar Phase 4', 'HBR Layout',
#        'Gnana bharathi', 'Maruthi Sevanagar', 'Uttarahalli Hobli',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df2.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Bangalore local.csv', index=False)

# %%
b=df2.locality.unique()
len(b)
# Out:
# 880

# %%
df3=pd.read_csv('Chennai_rent.csv')

# %%
df3.head()
# Out:
#   seller_type  bedroom layout_type      property_type     locality   price  \
# 0       OWNER      3.0         BHK          Apartment     Ambattur  17,000
# 1       OWNER      2.0         BHK          Apartment  Kelambakkam  16,000
# 2       OWNER      2.0         BHK          Apartment        Adyar  20,000
# 3       OWNER      2.0         BHK          Apartment    Sembakkam  14,000
# 4       OWNER      1.0         BHK  Independent House    Mogappair   7,000
#
#      area    furnish_type     bathroom
# 0  1570.0  Semi-Furnished  2 bathrooms
# 1  1402.0  Semi-Furnished  2 bathrooms
# 2   800.0  Semi-Furnished  2 bathrooms
# 3  1180.0     Unfurnished  2 bathrooms
# 4   400.0     Unfurnished  1 bathrooms

# %%
df3.locality.unique()
# Out:
# array(['Ambattur', 'Kelambakkam', 'Adyar', 'Sembakkam', 'Mogappair',
#        'Choolaimedu', 'Medavakkam', 'Vadapalani', 'Perumbakkam',
#        'Thirumullaivoyal', 'Ambattur INDUSTRIAL ESTATE', 'Urapakkam',
#        'Palavakam', 'Kolathur', 'Madhanandapuram', 'Perungudi', 'Kilpauk',
#        'Sholinganallur', 'Valasaravakkam', 'Mylapore Devandavakkam',
#        'Ramavaram', 'Ayanavaram', 'Guduvancheri', 'Kattupakkam',
#        'Chromepet', 'Vinayagapuram', 'Besant Nagar', 'T Nagar',
#        'West Mambalam', 'Pallikaranai', 'Nanganallur', 'Thiruvanmiyur',
#        'Royapettah', 'Periyamet', 'Potheri', 'Virugambakkam',
#        'Poonamallee', 'Maduravoyal', 'Perambur', 'Velachery',
#        'Iyappanthangal', 'Mugalivakkam', 'Madipakkam', 'Aminjikarai',
#        'Chetpet', 'Mogappair East', 'Avadi', 'George Town',
#        'Purasawalkam', 'Alwarpet', 'Alandur', 'Saidapet', 'Kovilambakkam',
#        'Teynampet', 'Kovalam', 'Annanagar West', 'Pallavan Nagar',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df3.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Chennai local.csv', index=False)

# %%
c=df3.locality.unique()
len(c)
# Out:
# 403

# %%
df4=pd.read_csv('Delhi_rent.csv')

# %%
df4.head()
# Out:
#   seller_type  bedroom layout_type      property_type              locality  \
# 0       OWNER      1.0          RK   Studio Apartment           Vasant Kunj
# 1       OWNER      1.0         BHK          Apartment  Sector-B Vasant Kunj
# 2       OWNER      2.0         BHK          Apartment                 Saket
# 3       OWNER      1.0         BHK          Apartment       New Ashok Nagar
# 4       OWNER      2.0         BHK  Independent Floor           laxmi nagar
#
#     price    area    furnish_type     bathroom
# 0   9,999   500.0       Furnished  1 bathrooms
# 1  18,500   750.0  Semi-Furnished  1 bathrooms
# 2  13,000  1050.0  Semi-Furnished  2 bathrooms
# 3  10,000   550.0       Furnished  1 bathrooms
# 4  13,500   648.0       Furnished  1 bathrooms

# %%
df4.locality.unique()
# Out:
# array(['Vasant Kunj', 'Sector-B Vasant Kunj', 'Saket', 'New Ashok Nagar',
#        'laxmi nagar', 'Malviya Nagar', 'Sector-17 Rohini', 'Khanpur',
#        'Pitampura', 'Uttam Nagar', 'Janakpuri', 'vikaspuri', 'Shadipur',
#        'Karol Bagh', 'Palam', 'Baprola', 'Burari', 'Pochanpur Colony',
#        'Kalkaji', 'Munirka', 'Lajpat Nagar', 'Dr Mukherji Nagar',
#        'Vasant Vihar', 'Sector 22 Dwarka', 'Sector 6 Dwarka',
#        'Model Town', 'Ghitorni', 'Sector 23 Dwarka', 'Dwarka Mor',
#        'Chattarpur', 'Sector 8 Dwarka', 'Wazirabad', 'Mahavir Enclave',
#        'Neeti Bagh', 'mayur vihar phase 1', 'Panchsheel Park',
#        'Defence Colony', 'Mayur Vihar Phase 3', 'Aya Nagar',
#        'Tilak Nagar', 'Shalimar Bagh', 'Sector 1 Dwarka', 'Ramesh Nagar',
#        'Jaunapur', 'Ashok Vihar', 'Sector 8 Rohini', 'West Shalimar Bagh',
#        'Samalka', 'Vijay Nagar', 'Neb Sarai', 'Moti Bagh', 'Manglapuri',
#        'Karampura', 'Greater Kailash', 'Sahibabad', 'SULTANPUR',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df4.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Delhi local.csv', index=False)

# %%
d=df4.locality.unique()
len(d)
# Out:
# 663

# %%
df5=pd.read_csv('Hyderabad_rent.csv')

# %%
df5.head()
# Out:
#   seller_type  bedroom layout_type      property_type          locality  \
# 0       OWNER        1          RK   Studio Apartment   Serilingampally
# 1       OWNER        5         BHK              Villa  Sri Nagar Colony
# 2       OWNER        2         BHK  Independent House          Shaikpet
# 3       OWNER        3         BHK          Apartment      Nanakramguda
# 4       OWNER        3         BHK          Apartment          Kondapur
#
#     price  area    furnish_type     bathroom
# 0   6,720   320       Furnished  1 bathrooms
# 1  36,000  3000  Semi-Furnished  4 bathrooms
# 2  11,000   900  Semi-Furnished  2 bathrooms
# 3  45,000  2165     Unfurnished  3 bathrooms
# 4  20,000  1600  Semi-Furnished  3 bathrooms

# %%
df5.locality.unique()
# Out:
# array(['Serilingampally', 'Sri Nagar Colony', 'Shaikpet', 'Nanakramguda',
#        'Kondapur', 'manneguda', 'Manikonda', 'Jubilee Hills',
#        'Gajularamaram', 'Narsingi', 'Begumpet', 'Kukatpally', 'LB Nagar',
#        'Banjara Hills', 'Nallagandla Gachibowli', 'Trimalgherry',
#        'Meerpet', 'Gachibowli', 'AS Rao Nagar', 'Nizampet', 'Kapra',
#        'Puppalaguda', 'Chandanagar', 'Aminpur', 'Hitech City', 'Madhapur',
#        'Hastinapuram', 'Mehdipatnam', 'Hyderabad Shah Guda', 'Moosapet',
#        'Syed Ali Guda', 'Kothapet', 'Rani Gunj', 'Suraram', 'Hafeezpet',
#        'Sanath Nagar', 'Pocharam', 'Old Bowenpally', 'Attapur', 'Kadthal',
#        'Abids', 'Amberpet', 'Nagaram Hyderabad South', 'Miyapur',
#        'West Marredpally', 'Bandlaguda Jagir', 'Saroornagar',
#        'Dilsukh Nagar', 'Alwal', 'BHEL', 'Quthbullapur', 'Bapu Nagar',
#        'Adibatla', 'Toli Chowki', 'Nagole', 'Shamshabad', 'Mettuguda',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df5.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Hyderabad local.csv', index=False)

# %%
e=df5.locality.unique()
len(e)
# Out:
# 494

# %%
df6=pd.read_csv('Kolkata_rent.csv')

# %%
df6.head()
# Out:
#   seller_type  bedroom layout_type      property_type       locality   price  \
# 0       OWNER        2         BHK  Independent Floor        Sodepur   6,000
# 1       OWNER        1          RK   Studio Apartment  south dum dum   4,000
# 2       OWNER        1          RK   Studio Apartment      Sector 22   6,500
# 3       OWNER        9         BHK  Independent House   Lake Gardens     1.5
# 4       OWNER        3         BHK  Independent House          Dhapa  26,000
#
#    area    furnish_type     bathroom
# 0   600     Unfurnished  1 bathrooms
# 1   150  Semi-Furnished  1 bathrooms
# 2   350  Semi-Furnished  1 bathrooms
# 3  6500     Unfurnished  6 bathrooms
# 4  1200       Furnished  2 bathrooms

# %%
df6.locality.unique()
# Out:
# array(['Sodepur', 'south dum dum', 'Sector 22', 'Lake Gardens', 'Dhapa',
#        'Dum Dum', 'Kankurgachi', 'Kasba', 'Sarsuna', 'Mukundapur', 'Joka',
#        'Jadavpur', 'Nayabad', 'Santoshpur', 'Jodhpur Park',
#        'Ganguly Bagan', 'Panihati', 'New Town', 'Rahara', 'Bansdroni',
#        'Salt Lake City', 'Santragachi', 'Madhyamgram', 'Picnic Garden',
#        'Dankuni', 'New Barrakpur', 'Tollygunge', 'Haltu', 'Uluberia',
#        'Baguihati', 'Maniktala', 'Konnagar', 'Bhowanipore', 'Kamalgazi',
#        'Kamdahari', 'Jagadishpur', 'Agarpara', 'Thakurpukur',
#        'Beliaghata', 'Madurdaha Hussainpur', 'Kaikhali', 'Gupta Colony',
#        'birati', 'Gariahat', 'Ward No 113', 'Shibpur',
#        'Howrah Railway Station', 'Behala', 'New Alipore', 'Rajarhat',
#        'Ichhapur Defence Estate', 'Uttarpara Kotrung', 'Sector 25',
#        'Keshtopur', 'Garia', 'Bhawanipur', 'Topsia', 'Howrah',
#        'Bramhapur', 'Netaji Nagar', 'Regent Park', 'Tagore Park',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df6.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Kolkata local.csv', index=False)

# %%
f=df6.locality.unique()
len(f)
# Out:
# 410

# %%
df7=pd.read_csv('Mumbai_rent.csv')

# %%
df7.head()
# Out:
#   seller_type  bedroom layout_type      property_type          locality  \
# 0       OWNER      4.0         BHK  Independent Floor      Andheri West
# 1       OWNER      1.0         BHK          Apartment      Andheri East
# 2       OWNER      1.0         BHK          Apartment    Mira Road East
# 3       OWNER      2.0         BHK          Apartment     Goregaon East
# 4       OWNER      2.0         BHK  Independent Floor  Ville Parle West
#
#     price    area    furnish_type     bathroom
# 0  56,800  1201.0  Semi-Furnished  2 bathrooms
# 1  26,000   595.0       Furnished  1 bathrooms
# 2  12,500   560.0     Unfurnished  2 bathrooms
# 3  36,000   860.0  Semi-Furnished  2 bathrooms
# 4  65,000  1000.0       Furnished  3 bathrooms

# %%
df7.locality.unique()
# Out:
# array(['Andheri West', 'Andheri East', 'Mira Road East', 'Goregaon East',
#        'Ville Parle West', 'Koper Khairane', 'Malad West',
#        'Borivali West', 'Malad East', 'Juhu', 'Kalyan West', 'Dahisar',
#        'Thane West', 'Powai', 'Lower Parel', 'Chembur', 'Rabale',
#        'Dombivali East', 'Goregaon West', 'Ulwe', 'Airoli', 'Ghansoli',
#        'Bhandup East', 'Panvel', 'Parel', 'Santacruz East', 'Agripada',
#        'Bhandup West', 'Vikhroli', 'Vasai West', 'Belapur', 'Kalwa',
#        'Ghatkopar East', 'Mulund West', 'Jogeshwari East',
#        'Kandivali West', 'kasaradavali thane west', 'Mahim', 'Karanjade',
#        'Mulund East', 'Bandra West', 'Dahisar Navi mumbai', 'Seawoods',
#        'Naigaon East', 'Ghatkopar West', 'Bandra East', 'Worli',
#        'Mira Road West', 'Karal', 'Dahisar West', 'Kurla', 'Nerul',
#        'Sarsole', 'Thakurli', 'lokgram', 'Ville Parle East', 'Kanjurmarg',
#        'Dadar East', 'Greater Khanda', 'Virar West', 'Virar',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df7.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Mumbai local.csv', index=False)

# %%
g=df7.locality.unique()
len(g)
# Out:
# 729

# %%
df8=pd.read_csv('Pune_rent.csv')

# %%
df8.head()
# Out:
#   seller_type  bedroom layout_type      property_type  locality   price  area  \
# 0       OWNER        1         BHK  Independent Floor   Mundhwa   6,750   450
# 1       OWNER        2         BHK          Apartment     Wakad  18,000   916
# 2       OWNER        3         BHK          Apartment   Wagholi  16,500  1085
# 3       OWNER        1          RK   Studio Apartment   Kothrud   8,000   250
# 4       OWNER        2         BHK          Apartment  Yerawada  25,000  1005
#
#      furnish_type     bathroom
# 0     Unfurnished  1 bathrooms
# 1     Unfurnished  2 bathrooms
# 2  Semi-Furnished  3 bathrooms
# 3       Furnished  1 bathrooms
# 4  Semi-Furnished  2 bathrooms

# %%
df8.locality.unique()
# Out:
# array(['Mundhwa', 'Wakad', 'Wagholi', 'Kothrud', 'Yerawada', 'Ganj Peth',
#        'Pimple Saudagar', 'Hinjewadi', 'Dhanori', 'Nigdi', 'Bopkhel',
#        'Viman Nagar', 'Dhayari', 'Pimple Nilakh', 'Chakan', 'Chinchwad',
#        'Kharadi', 'Kalyani Nagar', 'Ravet', 'Lohegaon', 'Parvati Darshan',
#        'Chikhali', 'Baner', 'Pimple Gurav', 'Bhosari', 'Undri', 'Dighi',
#        'Sus', 'Hadapsar', 'Sinhgad Road', 'Tathawade', 'Ambegaon 1',
#        'Karve Nagar', 'Bavdhan', 'Warje', 'Kondhwa', 'Manjari', 'Daund',
#        'Manjari Budruk', 'Wadegaon', 'New Sangavi', 'Pimpri', 'Alandi',
#        'Gahunje', 'Wadgaon Sheri', 'Sopan Baug', 'Katraj', 'Bhawani Peth',
#        'Anand Nagar', 'Siddharth nagar', 'Thergaon', 'Talwade',
#        'Tingre Nagar', 'Akurdi', 'Sangamvadi', 'Pirangut', 'Kasba Peth',
#        'Wanowrie', 'Aundh', 'Balewadi', 'Handewadi', 'New Kalyani Nagar',
#        'Punawale', 'Fursungi', 'Budhwar Peth', 'Dhayari Phata',
# ...

# %%
import pandas as pd

# Assuming df1.locality.unique() returns a NumPy array
a = df8.locality.unique()

# Convert NumPy array to pandas DataFrame
a_df = pd.DataFrame(a, columns=['locality'])

# Save DataFrame to CSV
a_df.to_csv('Pune local.csv', index=False)

# %%
h=df8.locality.unique()
len(h)
# Out:
# 459

# %%
print(len(a), len(b), len(c), len(d), len(e), len(f), len(g), len(h))
# Out:
# 203 880 403 663 494 410 729 459
